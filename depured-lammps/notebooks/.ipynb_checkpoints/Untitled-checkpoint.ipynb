# %%
import os
import sys
import importlib
if '../utils' not in sys.path:
    sys.path.insert(0,'../utils')
import lmp
import lmpsetup
import analysis
import numpy as np
import matplotlib.pyplot as plt

importlib.reload(lmp);
importlib.reload(lmpsetup);
importlib.reload(analysis);

# %%
importlib.reload(lmp);
importlib.reload(lmpsetup);
importlib.reload(analysis);

d = '/home/adria/perdiux/prod/lammps/dignon/hnRPA/RE-T-hnRPA'
re = analysis.Analysis(oliba_wd=d, temper=True)

# %%
rgs = re.rg(calc_from="mdtraj")
rgs_log = re.rg(calc_from="lmp")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5748478a41be> in <module>
# ----> 1 rgs = re.rg(calc_from="mdtraj")
#       2 rgs_log = re.rg(calc_from="lmp")
#
# ~/scripts/depured-lammps/utils/analysis.py in rg(self, calc_from)
#     124     def rg(self, calc_from='lmp'):
#     125         if self.temper:
# --> 126             data = self.get_lmp_temper_data()
#     127         else:
#     128             data = self.get_lmp_data()
#
# ~/scripts/depured-lammps/utils/lmp.py in get_lmp_temper_data(self, lmp_directories, progress)
#     109                 dends.append(data_end)
#     110                 dstarts = data_start
# --> 111         dmin = np.array(dends).min()
#     112         for i, lmp in enumerate(lmps):
#     113             dat = np.loadtxt(os.path.join(d, lmp), skiprows=dstarts, max_rows=dmin - dstarts)
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.ylabel("Rg (Ang)")
plt.xlabel("Temperature index (Increasing T)")
plt.plot(rgs.mean(axis=1)*10, label='MDTRAJ')
plt.plot(rgs_log.mean(axis=1), '--', label='LAMMPS')
plt.legend()

# %%
plt.plot(re.flory_scaling_fit(r0=5.5)[0]);
print(rgs,re.flory_scaling_fit(r0=5.5)[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-6e00d33eff10> in <module>
# ----> 1 plt.plot(re.flory_scaling_fit(r0=5.5)[0]);
#       2 print(rgs,re.flory_scaling_fit(r0=5.5)[0])
#
# ~/scripts/depured-lammps/utils/analysis.py in flory_scaling_fit(self, r0)
#      84             tot_means.append(means)
#      85         return np.array(tot_ijs), np.array(tot_means)
# ---> 86
#      87     def flory_scaling_fit(self, r0=None):
#      88         tot_ijs, tot_means = self.ij_from_contacts()
#
# ~/scripts/depured-lammps/utils/analysis.py in ij_from_contacts(self)
#      69         return contact_maps
#      70
# ---> 71     def ij_from_contacts(self):
#      72         if self.contacts is None:
#      73             self.contact_map()
#
# ~/scripts/depured-lammps/utils/analysis.py in contact_map(self, use_jit)
#      28     def contact_map(self, use_jit=False):
# ...

# %%
fig = plt.figure(num=None, figsize=(8, 6), frameon=False)
ijs, means = re.ij_from_contacts()
for i, ij in enumerate(ijs):
    mean = means[i]
    plt.xlabel("|i-j|")
    plt.ylabel(r'dij ($\AA$)')
    plt.plot(ij, mean/10, label=i)
plt.plot(ij, ij**0.33, label="0.33 flory")
plt.legend();

# %%
print([[]]*6)
# Out:
# [[], [], [], [], [], []]

# %%
import mdtraj as md
import numpy as np
import itertools
ti = time.time()
t = md.load('/home/adria/perdiux/prod/lammps/dignon/hnRPA/T-hnRPA/150.0/hps_traj.xtc', 
    top='/home/adria/perdiux/prod/lammps/dignon/hnRPA/T-hnRPA/150.0/hps_trj.pdb', 
    stride=1)
#d = md.compute_contacts(t, scheme='ca')
pairs = list(itertools.product(range(t.top.n_atoms-1), range(1,t.top.n_atoms)))
d = md.compute_distances(t, pairs)   #these 2 are the slowest steps
d = md.geometry.squareform(d, pairs) #these 2 are the slowest steps
d = d.mean(0)
Rij = [np.diagonal(d,i).mean()  for i in range(d.shape[0])]
print("TIME SPENT", time.time()- ti)
# Out:
# TIME SPENT 44.82819485664368

# %%
plt.plot(Rij)

# %%
import os
import sys
import time
import importlib
if '../utils' not in sys.path:
    sys.path.insert(0,'../utils')
import lmp
import lmpsetup
import analysis
import numpy as np
import matplotlib.pyplot as plt

importlib.reload(lmp);
importlib.reload(lmpsetup);
importlib.reload(analysis);

ti = time.time()

d = '/home/adria/perdiux/prod/lammps/dignon/hnRPA/T-hnRPA/150.0'
re = analysis.Analysis(oliba_wd=d, temper=False)
re.contact_map(use='md')

print("TIME SPENT", time.time() - ti)
# Out:
# hps
# ['/home/adria/perdiux/prod/lammps/dignon/hnRPA/T-hnRPA/150.0/hps_traj.xtc']
# START CONTACT CALC
# TIME SPENT 45.09542727470398

# %%
import os
import sys
import time
import importlib
if '../utils' not in sys.path:
    sys.path.insert(0,'../utils')
import lmp
import lmpsetup
import analysis
import numpy as np
import matplotlib.pyplot as plt

importlib.reload(lmp);
importlib.reload(lmpsetup);
importlib.reload(analysis);

ti = time.time()

d = '/home/adria/perdiux/prod/lammps/dignon/hnRPA/T-hnRPA/150.0'
re = analysis.Analysis(oliba_wd=d, temper=False)
re.ij_from_contacts()

print("TIME SPENT", time.time() - ti)
# Out:
# hps
# ['/home/adria/perdiux/prod/lammps/dignon/hnRPA/T-hnRPA/150.0/hps_traj.xtc']
# START CONTACT CALC
# TIME SPENT 15.406499147415161
