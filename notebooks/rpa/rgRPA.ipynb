# %%
# %load_ext autoreload
# %autoreload 2
import rgRPA

# %%
t = rgRPA.rgRPA(u=0.1, seqname='CPEB4', phiTop=0.2, phisTop=0.1)
t.run()
# Out:
# 0.1 0.001
# 0.1 0.001
# 0.1 0.001 0.1
# 0.0002232142857142857
# 44800
# RG [  0.80234922   0.80234922 -34.78643621   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922  36.39113464   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922  36.39113464   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
#    0.80234922   0.80234922   0.80234922   0.80234922   0.80234922
# ...
