# %%
import plotter

# %%
p = plotter.Plotter()

# %%
p.index
# Out:
#                 Protein    I   Eps  Scale                 Name  \
# 0          12D_CPEB4_D4  100  80.0    1.0       1.0ls-100I-80e
# 1        12D_CPEB4_D4x2  100  80.0    1.0       12D_CPEB4_D4x2
# 2       12D_CPEB4_D4x50  100  80.0    1.0                   T0
# 3       12D_CPEB4_D4x50   67  80.0    1.0                   T1
# 4              7D_CPEB4  100  80.0    1.0       1.0ls-100I-80e
# 5            7D_CPEB4x2  100  80.0    1.0           7D_CPEB4x2
# 6           7D_CPEB4x50  100  80.0    1.0                   T0
# 7           7D_CPEB4x50   67  80.0    1.0                   T1
# 8                 CPEB4  100  80.0    1.0       1.0ls-100I-80e
# 9              CPEB4_D4  100  80.0    1.0       1.0ls-100I-80e
# 10           CPEB4_D4x2  100  80.0    1.0           CPEB4_D4x2
# 11          CPEB4_D4x50  100  80.0    1.0                   T0
# 12          CPEB4_D4x50   67  80.0    1.0                   T1
# 13              CPEB4x2  100  80.0    1.0              CPEB4x2
# ...

# %%
p.plot(observable='rg', plot_id=0, index=8)
p.plot(observable='rg', plot_id=0, index=9)
# Out:
# 17059
# 17059
# 17059
# 17059
# 17059
# 17059
# 17059
# 17059
# 17059
# 17059
# 17059
# 17059
# > Run Completed at 83.78% for CPEB4. Ran 83785000 steps for a total of 16758 frames
# > Taking frames every 2 for a total of 1000 to avoid strong correlations
# 17273
# 17273
# 17273
# 17273
# 17273
# 17273
# 17274
# 17273
# 17273
# 17273
# 17273
# 17273
# > Run Completed at 84.86% for CPEB4_D4. Ran 84855000 steps for a total of 16972 frames
# > Taking frames every 2 for a total of 1000 to avoid strong correlations
# array([[25.533754  , 24.63071133, 23.69972852, ..., 26.83363341,
#         27.88922954, 25.63548289],
#        [26.97516327, 28.70550296, 39.24239505, ..., 28.93929027,
#         25.46473277, 28.90149255],
#        [33.48628582, 29.62694539, 30.49504498, ..., 31.4967783 ,
#         28.97860967, 29.88774957],
#        ...,
#        [52.39245473, 40.08406745, 51.53891514, ..., 58.06817411,
#         51.7988408 , 45.90718303],
# ...
