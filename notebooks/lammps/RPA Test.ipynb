# %%
# %load_ext autoreload
# %autoreload 2

import fgRPA
import numpy as np
import matplotlib.pyplot as plt

# %%
phis = np.linspace(0.001,0.07,40)
ff = []
for phi in phis:
    ff.append(fgRPA.RPA(phi_m=phi).f())
# Out:
# (-1.0960243061288273e-05, 7.707616753375775e-09, -1.0960243061288273e-05, 7.707616753375775e-09)
# (-6.032883692425879e-05, 3.6547984592356384e-09, -6.032883692425879e-05, 3.6547984592356384e-09)
# (-0.00013671613206670457, 5.931575994500414e-09, -0.00013671613206670457, 5.931575994500414e-09)
# (-0.0002341663905408006, 9.574490914860389e-09, -0.0002341663905408006, 9.574490914860389e-09)
# (-0.0003491283528963181, 1.3149501813463786e-08, -0.0003491283528963181, 1.3149501813463786e-08)
# (-0.00047915562269328906, 8.917534361386082e-09, -0.00047915562269328906, 8.917534361386082e-09)
# (-0.0006224482902202912, 1.0640475989194491e-08, -0.0006224482902202912, 1.0640475989194491e-08)
# (-0.0007775960187175916, 6.083201253400931e-09, -0.0007775960187175916, 6.083201253400931e-09)
# (-0.0009434754331733204, 3.4164202453985975e-09, -0.0009434754331733204, 3.4164202453985975e-09)
# (-0.0011191614206743235, 2.23151569191413e-09, -0.0011191614206743235, 2.23151569191413e-09)
# ...

# %%
plt.plot(phis, ff)
plt.plot(phis, -phis*1.23465)

# %%
plt.plot(phis, ff+phis*1.23465)

# %%
import rgRPA

# %%
phis = np.linspace(0.001,0.07,40)
ff = []
# for phi in phis:
ff.append(rgRPA.rgRPA(phi_m=0.05).f(phi_m=0.05))
