# %%
# %load_ext autoreload
# %autoreload 2

import plotter
import lmpsetup

# %%
pl = plotter.Plotter()
pl.index
# Out:
#             Protein    I   Eps  Scale            Name  \
# 0      12D_CPEB4_D4  100  80.0    1.0  1.0ls-100I-80e
# 1    12D_CPEB4_D4x2  100  80.0    1.0  12D_CPEB4_D4x2
# 2   12D_CPEB4_D4x50  100  80.0    1.0              T0
# 3   12D_CPEB4_D4x50   67  80.0    1.0              T1
# 4          7D_CPEB4  100  80.0    1.0  1.0ls-100I-80e
# 5        7D_CPEB4x2  100  80.0    1.0      7D_CPEB4x2
# 6       7D_CPEB4x50  100  80.0    1.0              T0
# 7       7D_CPEB4x50   67  80.0    1.0              T1
# 8             CPEB4  100  80.0    1.0  1.0ls-100I-80e
# 9          CPEB4_D4  100  80.0    1.0  1.0ls-100I-80e
# 10       CPEB4_D4x2  100  80.0    1.0      CPEB4_D4x2
# 11      CPEB4_D4x50  100  80.0    1.0              T0
# 12      CPEB4_D4x50   67  80.0    1.0              T1
# 13          CPEB4x2  100  80.0    1.0         CPEB4x2
# 14         CPEB4x50  100  10.0    1.0  1.0ls-100I-10e
# 15         CPEB4x50  100  80.0    1.0  1.0ls-100I-80e
# ...

# %%
d = pl.plot(observable='clusters', index=11, plot_id=12, temperature=8)
# Out:
# > Run Completed at 19.27% for CPEB4_D4. Ran 19265000 steps for a total of 3854 frames
# <mdtraj.Trajectory with 3854 frames, 22000 atoms, 22000 residues, and unitcells>
# <mdtraj.Trajectory with 1000 frames, 22000 atoms, 22000 residues, and unitcells>
# > Taking frames every 2 for a total of 1000 to avoid strong correlations
# [<mdtraj.Trajectory with 1000 frames, 22000 atoms, 22000 residues, and unitcells at 0x7f132e9a8b90>]
# No handles with labels found to put in legend.

# %% [markdown]
# # Summary

# %% [markdown]
# This week we want to simulate and go quantitative for all the multichain cases :
#
#
# 1. Generate **more chain simulations** DONE
#
#
# 2. **Dimers and interaction effects** DONE

# %% [markdown]
# ### 1. Generate **more chain simulations**

# %%
pl.plot(observable='inter_r', index=10, plot_id=0, temperature=1);
# Out:
# > Run Completed at 100.00% for CPEB4_D4. Ran 100000000 steps for a total of 2001 frames
# > Taking frames every 2 for a total of 1000 to avoid strong correlations
# No handles with labels found to put in legend.

# %%
import numpy as np
np.abs(np.array([-250,250])).sum()
# Out:
# 500

# %%
pl.plot(observable='rg', plot_id=0, index=14)
pl.plot(observable='rg', plot_id=0, index=15)
# Out:
# > Run Completed at 39.35% for None. Ran 39350000 steps for a total of 788 frames
# > Taking frames every -1 for a total of 1000 to avoid strong correlations
# > Run Completed at 34.45% for None. Ran 34450000 steps for a total of 690 frames
# > Taking frames every -1 for a total of 1000 to avoid strong correlations
# array([[48.31777813, 49.12426233, 48.8613994 , ..., 29.05880691,
#         29.06472483, 29.12747004],
#        [50.42425698, 50.41531488, 50.30623211, ..., 30.26891609,
#         30.01894454, 29.12747004],
#        [48.30083681, 48.19142988, 48.85568667, ..., 31.74333434,
#         31.38574259, 29.12747004],
#        ...,
#        [53.797216  , 53.24690139, 52.21416243, ..., 39.9890484 ,
#         36.97237138, 29.12747004],
#        [60.72700438, 62.1452288 , 63.05063023, ..., 38.72746114,
#         37.46774879, 29.12747004],
#        [58.55258546, 54.08975637, 58.42615424, ..., 41.10882319,
#         37.60210957, 29.12747004]])
