# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import fgRPA_ucst as fgu
import matplotlib.pyplot as plt

WT_COL='darkblue'
D7_COL='royalblue'

D4_COL = 'red'
D12_COL = 'orange'

# %%
find_cri=True
phis_mM = 100
ehs = [0,0]
umax=None

u_wt, wt_sp1, wt_sp2, wt_bi1, wt_bi2 = fgu.fgRPA_ucst(seqname='CPEB4', 
                                            find_cri=find_cri, 
                                            phis_mM=phis_mM, 
                                            ehs=ehs, 
                                            umax=2.5, 
                                            parallel=False).run()
# Out:
# Seq: CPEB4 = ...
# phi_s= 0.0018 r_res = 1 , r_con = 1 , r_sal = 1 , eta = 1
# ehs : 0 0
# Critical point found in 5.447142839431763 s
# u_cri = 2.0650e+00 T*_cri = 0.4843 , phi_cri = 8.51806406e-03
# [2.07 2.08 2.09 2.1  2.11 2.12 2.13 2.14 2.15 2.16 2.17 2.18 2.19 2.2
#  2.2  2.3  2.4  2.5 ]
# 2.07 0.00734092280090309 0.009889550177696748 sp done!
# 2.07 0.00660480431022599 0.010879347383623197 bi done!
# 2.0799999999999996 0.006588591619877471 0.011031397811226229 sp done!
# 2.0799999999999996 0.005929732457889724 0.012134537592348853 bi done!
# 2.0899999999999994 0.006118318640232547 0.011893090084357731 sp done!
# 2.0899999999999994 0.0044702500985751865 0.014418699141783956 bi done!
# 2.099999999999999 0.005762569408812748 0.012642177139385188 sp done!
# 2.099999999999999 0.003918822867241667 0.015799676397046093 bi done!
# 2.109999999999999 0.0054729630331667115 0.013327055279950902 sp done!
# 2.109999999999999 0.00352075193720391 0.017005995158034807 bi done!
# ...

# %%
find_cri=True
phis_mM = 100
ehs = [0,0]
umax=None

u_d4, d4_sp1, d4_sp2, d4_bi1, d4_bi2 = fgu.fgRPA_ucst(seqname='CPEB4_D4', 
                                            find_cri=find_cri, 
                                            phis_mM=phis_mM, 
                                            ehs=ehs, 
                                            umax=2.5, 
                                            parallel=False).run()
# Out:
# Seq: CPEB4_D4 = ...
# phi_s= 0.0018 r_res = 1 , r_con = 1 , r_sal = 1 , eta = 1
# ehs : 0 0
# Critical point found in 4.12009596824646 s
# u_cri = 1.9805e+00 T*_cri = 0.5049 , phi_cri = 7.37678373e-03
# [1.99 2.   2.01 2.02 2.03 2.04 2.05 2.06 2.07 2.08 2.09 2.1  2.1  2.2
#  2.3  2.4  2.5 ]
# 1.99 0.006038714319646485 0.009015227646182775 sp done!
# 1.99 0.0054348428876818365 0.009916750410801053 bi done!
# 2.0 0.005542100466017196 0.009827758810995008 sp done!
# 2.0 0.004264439325210887 0.011729860871821067 bi done!
# 2.01 0.0051927184392823065 0.010494304118063383 sp done!
# 2.01 0.003749384418192788 0.012938651561774234 bi done!
# 2.02 0.004917174042333497 0.011088277833995474 sp done!
# 2.02 0.0036126141340178343 0.01434071488387407 bi done!
# 2.0300000000000002 0.004687777181414944 0.011637390015094319 sp done!
# 2.0300000000000002 0.0029615161122164054 0.014878874477251627 bi done!
# 2.04 0.004490543660110097 0.012155644721292385 sp done!
# ...

# %%
find_cri=True
phis_mM = 100
ehs = [0,0]
umax=None

u_d7, d7_sp1, d7_sp2, d7_bi1, d7_bi2 = fgu.fgRPA_ucst(seqname='CPEB4_7D', 
                                            find_cri=find_cri, 
                                            phis_mM=phis_mM, 
                                            ehs=ehs, 
                                            umax=2.5, 
                                            parallel=False).run()
# Out:
# Seq: CPEB4_7D = ...
# phi_s= 0.0018 r_res = 1 , r_con = 1 , r_sal = 1 , eta = 1
# ehs : 0 0
# Critical point found in 4.640934705734253 s
# u_cri = 1.9292e+00 T*_cri = 0.5183 , phi_cri = 6.98457129e-03
# [1.93 1.94 1.95 1.96 1.97 1.98 1.99 2.   2.01 2.02 2.03 2.04 2.05 2.06
#  2.07 2.08 2.09 2.1  2.1  2.2  2.3  2.4  2.5 ]
# 1.93 0.006572589909516889 0.007424395442981585 sp done!
# 1.93 0.006382764140823541 0.007612792455518994 bi done!
# 1.94 0.005578859113022549 0.008777601054434774 sp done!
# 1.94 0.0050209732011852175 0.009655361162848456 bi done!
# 1.95 0.005118715214535407 0.009600516716812753 sp done!
# 1.95 0.0038899519991655454 0.01160840649200636 bi done!
# 1.96 0.004790503044396946 0.010294833627148807 sp done!
# 1.96 0.0032975499436053127 0.012984390588996563 bi done!
# 1.97 0.004530776166753058 0.010924034026197363 sp done!
# 1.97 0.0029147641517465487 0.013934097630513618 bi done!
# 1.98 0.0043144187484034265 0.011513269313757775 sp done!
# ...

# %%
find_cri=True
phis_mM = 100
ehs = [0,0]
umax=None

u_d12, d12_sp1, d12_sp2, d12_bi1, d12_bi2 = fgu.fgRPA_ucst(seqname='CPEB4_12D', 
                                            find_cri=find_cri, 
                                            phis_mM=phis_mM, 
                                            ehs=ehs, 
                                            umax=2.5, 
                                            parallel=False).run()
# Out:
# Seq: CPEB4_12D = ...
# phi_s= 0.0018 r_res = 1 , r_con = 1 , r_sal = 1 , eta = 1
# ehs : 0 0
# Critical point found in 4.218398809432983 s
# u_cri = 1.8704e+00 T*_cri = 0.5347 , phi_cri = 4.21702097e-03
# [1.88 1.89 1.9  1.91 1.92 1.93 1.94 1.95 1.96 1.97 1.98 1.99 2.   2.1
#  2.2  2.3  2.4  2.5  2.6 ]
# 1.8800000000000001 0.0034280966836939043 0.00522497554324502 sp done!
# 1.8800000000000001 0.0030422141921217904 0.005927588034134907 bi done!
# 1.8900000000000001 0.0031441261199996835 0.005739829235963938 sp done!
# 1.8900000000000001 0.0028297135079997154 0.006313812159560332 bi done!
# 1.9000000000000001 0.002945969896672917 0.006172290683363273 sp done!
# 1.9000000000000001 0.0026513729070056255 0.0067895197516996 bi done!
# 1.9100000000000001 0.0027906296422187896 0.006565419639943876 sp done!
# 1.9100000000000001 0.001869598108538203 0.008352054118711509 bi done!
# 1.9200000000000002 0.0026619059429630804 0.0069354781058499244 sp done!
# ...

# %%
plt.plot(wt_bi1, 1/u_wt, color=WT_COL, label='WT')
plt.plot(wt_bi2, 1/u_wt, color=WT_COL)
plt.plot(d4_bi1, 1/u_d4, color=D4_COL, label='D4')
plt.plot(d4_bi2, 1/u_d4, color=D4_COL)
plt.legend()

# %%
plt.plot(wt_bi1, 1/u_wt, color=WT_COL, label='WT')
plt.plot(wt_bi2, 1/u_wt, color=WT_COL)
plt.plot(d7_bi1, 1/u_d7, color=D7_COL, label='D7')
plt.plot(d7_bi2, 1/u_d7, color=D7_COL)
plt.legend()

# %%
plt.plot(d12_bi1, 1/u_d12, color=D12_COL, label='12D')
plt.plot(d12_bi2, 1/u_d12, color=D12_COL)
plt.plot(d4_bi1, 1/u_d4, color=D4_COL, label='D4')
plt.plot(d4_bi2, 1/u_d4, color=D4_COL)
plt.legend()

# %% [markdown]
# ### Eps func

# %%
find_cri=True
phis_mM = 100
ehs = [0,0]
umax=None

u_wt_e, wt_sp1_e, wt_sp2_e, wt_bi1_e, wt_bi2_e = fgu.fgRPA_ucst(seqname='CPEB4', 
                                            find_cri=find_cri, 
                                            phis_mM=phis_mM, 
                                            ehs=ehs, 
                                            umax=2.1, 
                                            epsfun=True,
                                            parallel=False).run()
# Out:
# Seq: CPEB4 = ...
# phi_s= 0.0018 r_res = 1 , r_con = 1 , r_sal = 1 , eta = 1
# ehs : 0 0
# Critical point found in 7.6291162967681885 s
# u_cri = 1.9431e+00 T*_cri = 0.5147 , phi_cri = 1.00789008e-02
# [1.95 1.96 1.97 1.98 1.99 2.   2.01 2.02 2.03 2.04 2.05 2.06 2.07 2.08
#  2.09 2.1  2.1  2.2 ]
# 1.95 0.008246456127376659 0.012378797828305066 sp done!
# 1.95 0.007421810514638993 0.013616677611135573 bi done!
# 1.96 0.0073822537379801025 0.01392733224083239 sp done!
# 1.96 0.005557049393704346 0.016936311975740144 bi done!
# 1.97 0.006819192483853133 0.015188152292202564 sp done!
# 1.97 0.004534278453781769 0.018722311958959195 bi done!
# 1.98 0.006390680471200064 0.01632839972384785 sp done!
# 1.98 0.0035851001157130454 0.022613022630435704 bi done!
# 1.99 0.006042070101021911 0.017403304209886977 sp done!
# 1.99 0.003448052612659048 0.02308445705029175 bi done!
# 2.0 0.005747420620413867 0.0184394235539555 sp done!
# 2.0 0.003016165008637181 0.024967074602308948 bi done!
# ...

# %%
plt.plot(wt_bi1_e, u_wt_e, color=D12_COL, label='E')
plt.plot(wt_bi2_e, u_wt_e, color=D12_COL)
# plt.plot(wt_bi1, 1/u_wt, color=D12_COL, label='NOE')
# plt.plot(wt_bi2, 1/u_wt, color=D12_COL)
plt.legend()
