# %%
# %load_ext autoreload
# %autoreload 2

import lmp
import plotter
import analysis
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
T=3

avail = plotter.Plotter()
display(HTML(avail.index.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Protein</th>
#       <th>I</th>
#       <th>Eps</th>
#       <th>Scale</th>
#       <th>Name</th>
#       <th>FullPath</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12D_CPEB4_D4</td>
#       <td>100</td>
#       <td>80.0</td>
#       <td>1.0</td>
#       <td>1.0ls-100I-80e</td>
#       <td>/home/adria/data/prod/lammps/12D_CPEB4_D4/x1/1.0ls-100I-80e</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7D_CPEB4</td>
#       <td>100</td>
#       <td>80.0</td>
#       <td>1.0</td>
#       <td>1.0ls-100I-80e</td>
#       <td>/home/adria/data/prod/lammps/7D_CPEB4/x1/1.0ls-100I-80e</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CPEB4</td>
#       <td>100</td>
#       <td>80.0</td>
#       <td>1.0</td>
#       <td>1.0ls-100I-80e</td>
#       <td>/home/adria/data/prod/lammps/CPEB4/x1/1.0ls-100I-80e</td>
#     </tr>
# ...

# %% [markdown]
# ### DISTANCES

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, temperature=T)
# Out:
# Saving data

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, index2=2, temperature=T)
# Out:
# Saving data

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, index2=2, temperature=T, log=True)
# Out:
# /home/adria/scripts/lammps/lammps/plotter.py:209: RuntimeWarning: divide by zero encountered in true_divide
#   cont_map = np.log(cont_map/b_cont_map)
# /home/adria/scripts/lammps/lammps/plotter.py:209: RuntimeWarning: invalid value encountered in true_divide
#   cont_map = np.log(cont_map/b_cont_map)
# Saving data

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, index2=2, temperature=T, frac=True)
# Out:
# /home/adria/scripts/lammps/lammps/plotter.py:212: RuntimeWarning: divide by zero encountered in true_divide
#   cont_map = cont_map/b_cont_map
# /home/adria/scripts/lammps/lammps/plotter.py:212: RuntimeWarning: invalid value encountered in true_divide
#   cont_map = cont_map/b_cont_map
# Saving data

# %% [markdown]
# ### CONTACTS

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, temperature=T, contacts=True)
# Out:
# Saving data

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, index2=2, temperature=T, contacts=True)
# Out:
# Saving data

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, index2=2, temperature=T, log=True, contacts=True)
# Out:
# /home/adria/scripts/lammps/lammps/plotter.py:209: RuntimeWarning: divide by zero encountered in log
#   cont_map = np.log(cont_map/b_cont_map)
# Saving data

# %%
p = plotter.Plotter()
p.plot(observable='distance_map', index=1, index2=2, temperature=T, contacts=True, frac=True)
# Out:
# /home/adria/scripts/lammps/lammps/plotter.py:212: RuntimeWarning: divide by zero encountered in true_divide
#   cont_map = cont_map/b_cont_map
# /home/adria/scripts/lammps/lammps/plotter.py:212: RuntimeWarning: invalid value encountered in true_divide
#   cont_map = cont_map/b_cont_map
# Saving data
