# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
kdsm = np.loadtxt('../bin/foo/b2-d.txt')
plt.figure(num=None, figsize=(8,6))
plt.title("Kd over residues for CPEB4\u03944")
plt.xlabel("Residue number")
plt.ylabel("Kd")
plt.semilogy(kdsm[0], kdsm[1], label="Kd")
# plt.axvspan(402, 410, alpha=0.5, color='red', label="E4")
# plt.legend();

# %%
kdsp = np.loadtxt('../bin/foo/b2+d.txt')
plt.figure(num=None, figsize=(8,6))
plt.title("Kd over residues for CPEB4\u03944")
plt.xlabel("Residue number")
plt.ylabel("Kd")
plt.semilogy(kdsp[0], kdsp[1], label="Kd")
# plt.axvspan(402, 410, alpha=0.5, color='red', label="E4")
# plt.legend();

# %%
print(kdsm)
# Out:
# [[ 4.40000000e+02  4.21000000e+02  4.19000000e+02  4.17000000e+02
#    4.16000000e+02  4.12000000e+02  4.11000000e+02  4.02000000e+02
#    3.99000000e+02  3.97000000e+02  3.95000000e+02  3.92000000e+02
#    3.87000000e+02  3.82000000e+02  3.79000000e+02  3.77000000e+02
#    3.76000000e+02  3.69000000e+02  3.67000000e+02  3.63000000e+02
#    3.62000000e+02  3.58000000e+02  3.50000000e+02  3.47000000e+02
#    3.36000000e+02  3.35000000e+02  3.19000000e+02  3.18000000e+02
#    3.16000000e+02  3.15000000e+02  2.80000000e+02  2.64000000e+02
#    2.51000000e+02  2.50000000e+02  1.86000000e+02  1.85000000e+02
#    1.47000000e+02  1.44000000e+02  1.36000000e+02  1.34000000e+02
#    1.32000000e+02  1.31000000e+02  1.30000000e+02  1.25000000e+02
#    1.21000000e+02  1.17000000e+02  1.16000000e+02  1.14000000e+02
#    1.12000000e+02  1.11000000e+02  1.09000000e+02  1.03000000e+02
#    9.30000000e+01  9.20000000e+01  8.90000000e+01  8.60000000e+01
# ...

# %%
print(kdsp)
# Out:
# [[ 3.00000000e+00  1.70000000e+01  2.30000000e+01  7.20000000e+01
#    7.30000000e+01  7.80000000e+01  7.90000000e+01  8.10000000e+01
#    8.60000000e+01  8.90000000e+01  9.20000000e+01  9.30000000e+01
#    1.03000000e+02  1.09000000e+02  1.11000000e+02  1.12000000e+02
#    1.14000000e+02  1.16000000e+02  1.17000000e+02  1.21000000e+02
#    1.25000000e+02  1.30000000e+02  1.31000000e+02  1.32000000e+02
#    1.34000000e+02  1.36000000e+02  1.44000000e+02  1.47000000e+02
#    1.85000000e+02  1.86000000e+02  2.50000000e+02  2.51000000e+02
#    2.64000000e+02  2.80000000e+02  3.15000000e+02  3.16000000e+02
#    3.18000000e+02  3.19000000e+02  3.35000000e+02  3.36000000e+02
#    3.47000000e+02  3.50000000e+02  3.58000000e+02  3.62000000e+02
#    3.63000000e+02  3.67000000e+02  3.69000000e+02  3.76000000e+02
#    3.77000000e+02  3.79000000e+02  3.82000000e+02  3.87000000e+02
#    3.92000000e+02  3.95000000e+02  3.97000000e+02  3.99000000e+02
# ...
